# %% [markdown]
# # Lab 2.4 &mdash; Gradient Descent by Hand
#
# **Level:** Beginner &nbsp;|&nbsp; **Est. time:** 25 min &nbsp;|&nbsp; **Day 1 &middot; Module 2 &mdash; Introduction to Deep Learning**
#
# ### What you'll do
# - Understand gradient descent as 'repeatedly step downhill'
# - Implement the gradient and the update step
# - See how the learning rate speeds up or destabilises learning
#
# > **How this lab works (experiential flow):** read the **Concept**, run the **Demo** to see it work, then complete **Your Turn** by replacing every `___` placeholder. Run the **grader** cell at the end &mdash; it prints `[PASS]` / `[FAIL]` / `[TODO]` and a final `Score`. Aim for a full score.
#
# **Reference:** [Module 2 slides &mdash; Gradient descent](../../presentation/day1-module2-introduction-to-deep-learning.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html) &nbsp;&middot;&nbsp; [All Module 2 labs](./index.html)

# %%
# Setup -- run me first
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"   # quiet TensorFlow logs (used in the advanced labs)
WORK = os.path.join(os.environ.get("TEMP") or os.environ.get("TMP") or "/tmp", "biaa-lab-02-04")
os.makedirs(WORK, exist_ok=True)
print("Working dir:", WORK)

# %% [markdown]
# ## Concept
# To minimise a function we **step downhill**: repeatedly move in the opposite direction of the
# **gradient** (slope). The step size is the **learning rate**. We minimise `f(x) = (x - 3)^2`,
# whose minimum is at `x = 3` and whose gradient is `2*(x - 3)`.

# %%
# DEMO -- one step downhill from x = 0
def f(x): return (x - 3) ** 2
x = 0.0
grad = 2 * (x - 3)          # slope at x = 0  -> -6 (downhill is to the right)
x = x - 0.1 * grad          # take a step
print("after one step, x =", round(x, 3), "f(x) =", round(f(x), 3))

# %% [markdown]
# ## Your Turn
# Implement the **gradient** and the **update step**, then run descent.

# %%
def grad(x):
    return ___   # TODO: derivative of (x-3)^2  =  2*(x-3)

def descend(x0=0.0, lr=0.1, steps=60):
    x = x0
    for _ in range(steps):
        x = ___   # TODO: step downhill: x - lr * grad(x)
    return x

try: print('converged to x =', round(descend(), 4))
except Exception as e: print('Fill the blanks, then re-run.', type(e).__name__)

# %%
# === Auto-grader: run after filling the blanks above ===
_results = []
def _rec(label, status, extra=""):
    _results.append(status); print(f"[{status}] {label}" + (f" -- {extra}" if extra else ""))
def expect(label, got, want):
    if got == "___" or got is None: _rec(label, "TODO")
    elif got == want: _rec(label, "PASS")
    else: _rec(label, "FAIL", f"got {got!r}")
def expect_true(label, fn):
    try: _rec(label, "PASS" if fn() else "FAIL")
    except Exception as e: _rec(label, "TODO", type(e).__name__)

expect_true("gradient is zero at the minimum (x=3)", lambda: grad(3) == 0)
expect_true("descent converges near x = 3", lambda: abs(descend() - 3) < 0.05)
expect_true("a tiny learning rate moves slowly (not there in 5 steps)", lambda: abs(descend(lr=0.001, steps=5) - 3) > 1.0)

_p = _results.count("PASS")
print(f"\nScore: {_p}/{len(_results)}")
print("All checks passed -- lab complete!" if _p == len(_results) else "Keep going: fill the blanks marked ___ and re-run.")

# %% [markdown]
# ---
# ### Key takeaway
# Every neural network trains this way: compute the gradient of the loss, step downhill, repeat. The learning rate is the single most important knob.
#
# [&#8592; All Module 2 labs](./index.html) &nbsp;&middot;&nbsp; [Module 2 slides](../../presentation/day1-module2-introduction-to-deep-learning.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html)
#
# <sub>&copy; 2026 Gheware DevOps &amp; Agentic AI &middot; Building Intelligent AI Agents &middot; devops.gheware.com &middot; Trainer: Rajesh Gheware</sub>
