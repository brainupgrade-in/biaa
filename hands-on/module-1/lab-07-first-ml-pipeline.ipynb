# %% [markdown]
# # Lab 1.7 &mdash; Your First ML Pipeline (scikit-learn)
#
# **Level:** 🟡 Intermediate &nbsp;|&nbsp; **Est. time:** 25 min &nbsp;|&nbsp; **Day 1 &middot; Module 1 &mdash; Understanding AI &amp; its Evolution**
#
# ### What you'll do
# - Run the standard ML pipeline: data, split, train, evaluate
# - Train a real classifier with scikit-learn
# - Score it on data it has never seen
#
# > **How this lab works (experiential flow):** read the **Concept**, run the **Demo** to see it work, then complete **Your Turn** by replacing every `___` placeholder. Run the **grader** cell at the end &mdash; it prints `[PASS]` / `[FAIL]` / `[TODO]` and a final `Score`. Aim for a full score.
#
# **Reference:** [Module 1 slides &mdash; How a model is built: the ML pipeline](../../presentation/day1-module1-understanding-ai-and-its-evolution.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html) &nbsp;&middot;&nbsp; [All Module 1 labs](./index.html)

# %%
# Setup -- run me first
import os
WORK = os.path.join(os.environ.get("TEMP") or os.environ.get("TMP") or "/tmp", "biaa-lab-01-07")
os.makedirs(WORK, exist_ok=True)
print("Working dir:", WORK)

# %% [markdown]
# ## Concept
# The five-step pipeline from the slides: **data &rarr; split &rarr; train &rarr; evaluate &rarr; predict**.
# The golden rule: judge the model on a **held-out test set** it never trained on.
#
# > Needs `scikit-learn` (`pip install scikit-learn`).

# %%
# DEMO -- load the data
from sklearn.datasets import load_iris
X, y = load_iris(return_X_y=True)
print("samples:", X.shape[0], "| features:", X.shape[1], "| classes:", sorted(int(c) for c in set(y)))

# %% [markdown]
# ## Your Turn
# Complete the pipeline: choose a **test fraction**, **fit** the model, and **predict** on the test set.

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

def run_pipeline():
    X, y = load_iris(return_X_y=True)
    test_frac = "___"   # TODO: a fraction like 0.25
    X_tr, X_te, y_tr, y_te = train_test_split(
        X, y, test_size=test_frac, random_state=0)
    clf = DecisionTreeClassifier(random_state=0)
    ___   # TODO: fit clf on the TRAINING data
    preds = ___   # TODO: predict on X_te
    return accuracy_score(y_te, preds)

try: print('test accuracy:', run_pipeline())
except Exception as e: print('Fill the blanks, then re-run.', type(e).__name__)

# %%
# === Auto-grader: run after filling the blanks above ===
_results = []
def _rec(label, status, extra=""):
    _results.append(status); print(f"[{status}] {label}" + (f" -- {extra}" if extra else ""))
def expect(label, got, want):
    if got == "___" or got is None: _rec(label, "TODO")
    elif got == want: _rec(label, "PASS")
    else: _rec(label, "FAIL", f"got {got!r}")
def expect_true(label, fn):
    try: _rec(label, "PASS" if fn() else "FAIL")
    except Exception as e: _rec(label, "TODO", type(e).__name__)

expect_true("pipeline runs and returns a number", lambda: isinstance(run_pipeline(), float))
expect_true("test accuracy >= 0.85", lambda: run_pipeline() >= 0.85)

_p = _results.count("PASS")
print(f"\nScore: {_p}/{len(_results)}")
print("All checks passed -- lab complete!" if _p == len(_results) else "Keep going: fill the blanks marked ___ and re-run.")

# %% [markdown]
# ---
# ### Key takeaway
# No rules written &mdash; the model **learned** the boundaries from labelled examples. This same shape powers every supervised lab this week.
#
# [&#8592; All Module 1 labs](./index.html) &nbsp;&middot;&nbsp; [Module 1 slides](../../presentation/day1-module1-understanding-ai-and-its-evolution.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html)
#
# <sub>&copy; 2026 Gheware DevOps &amp; Agentic AI &middot; Building Intelligent AI Agents &middot; devops.gheware.com &middot; Trainer: Rajesh Gheware</sub>
