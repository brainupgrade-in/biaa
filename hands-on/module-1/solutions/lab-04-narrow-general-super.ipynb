# %% [markdown]
# > ## &#9989; SOLUTION / ANSWER KEY &mdash; Lab 1.4
# > This is the **completed** notebook (all `___` blanks filled). For the student version, open
# > [`../lab-04-narrow-general-super.ipynb`](../lab-04-narrow-general-super.ipynb). Trainer use &mdash; or self-check after you've tried it yourself.

# %% [markdown]
# # Lab 1.4 &mdash; Narrow, General &amp; Super AI
#
# **Level:** 🟢 Beginner &nbsp;|&nbsp; **Est. time:** 15 min &nbsp;|&nbsp; **Day 1 &middot; Module 1 &mdash; Understanding AI &amp; its Evolution**
#
# ### What you'll do
# - Distinguish Narrow (ANI), General (AGI) and Super (ASI) AI
# - Classify systems into the right tier
# - Internalise that everything real today is narrow AI
#
# > **How this lab works (experiential flow):** read the **Concept**, run the **Demo** to see it work, then complete **Your Turn** by replacing every `___` placeholder. Run the **grader** cell at the end &mdash; it prints `[PASS]` / `[FAIL]` / `[TODO]` and a final `Score`. Aim for a full score.
#
# **Reference:** [Module 1 slides &mdash; Narrow / General / Super -- where we are](../../presentation/day1-module1-understanding-ai-and-its-evolution.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html) &nbsp;&middot;&nbsp; [All Module 1 labs](./index.html)

# %%
# Setup -- run me first
import os
WORK = os.path.join(os.environ.get("TEMP") or os.environ.get("TMP") or "/tmp", "biaa-lab-01-04")
os.makedirs(WORK, exist_ok=True)
print("Working dir:", WORK)

# %% [markdown]
# ## Concept
# - **ANI (Narrow):** superb at *specific* tasks. **Everything real today.**
# - **AGI (General):** human-level across *any* task. Does not exist yet.
# - **ASI (Super):** beyond human ability. Speculative.

# %%
# DEMO
print("ANI = a chess engine, a spam filter, ChatGPT  (all narrow!)")
print("AGI = a single AI that matches a human at ANY job (hypothetical)")
print("ASI = an AI beyond all human ability (speculative)")

# %% [markdown]
# ## Your Turn
# Label each scenario `"ANI"`, `"AGI"` or `"ASI"`. (Hint: only some are real today.)

# %%
answers = {
    "A model that beats grandmasters at Go":              "ANI",
    "An assistant that drafts emails and code":           "ANI",
    "One AI that can do ANY human job as well as a human": "AGI",
    "Self-driving car perception":                        "ANI",
    "A hypothetical mind smarter than all humans combined":"ASI",
    "A spam filter":                                      "ANI",
}
from collections import Counter
print(Counter(answers.values()))

# %%
# === Auto-grader: run after filling the blanks above ===
_results = []
def _rec(label, status, extra=""):
    _results.append(status); print(f"[{status}] {label}" + (f" -- {extra}" if extra else ""))
def expect(label, got, want):
    if got == "___" or got is None: _rec(label, "TODO")
    elif got == want: _rec(label, "PASS")
    else: _rec(label, "FAIL", f"got {got!r}")
def expect_true(label, fn):
    try: _rec(label, "PASS" if fn() else "FAIL")
    except Exception as e: _rec(label, "TODO", type(e).__name__)

KEY = {
  "A model that beats grandmasters at Go": "ANI",
  "An assistant that drafts emails and code": "ANI",
  "One AI that can do ANY human job as well as a human": "AGI",
  "Self-driving car perception": "ANI",
  "A hypothetical mind smarter than all humans combined": "ASI",
  "A spam filter": "ANI",
}
for k, want in KEY.items():
    expect(k[:36], answers.get(k), want)

_p = _results.count("PASS")
print(f"\nScore: {_p}/{len(_results)}")
print("All checks passed -- lab complete!" if _p == len(_results) else "Keep going: fill the blanks marked ___ and re-run.")

# %% [markdown]
# ---
# ### Key takeaway
# Our 'intelligent agents' this week are **narrow tools we direct and supervise** &mdash; capable, not autonomous beings. That keeps expectations and ethics grounded.
#
# [&#8592; All Module 1 labs](./index.html) &nbsp;&middot;&nbsp; [Module 1 slides](../../presentation/day1-module1-understanding-ai-and-its-evolution.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html)
#
# <sub>&copy; 2026 Gheware DevOps &amp; Agentic AI &middot; Building Intelligent AI Agents &middot; devops.gheware.com &middot; Trainer: Rajesh Gheware</sub>
