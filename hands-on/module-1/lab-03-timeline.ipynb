# %% [markdown]
# # Lab 1.3 &mdash; A Timeline of AI (and its Winters)
#
# **Level:** 🟢 Beginner &nbsp;|&nbsp; **Est. time:** 20 min &nbsp;|&nbsp; **Day 1 &middot; Module 1 &mdash; Understanding AI &amp; its Evolution**
#
# ### What you'll do
# - Assemble the major milestones of AI from 1950 to today
# - Add the deep-learning era events that ended the last 'AI winter'
# - Compute how long the field took to reach the modern moment
#
# > **How this lab works (experiential flow):** read the **Concept**, run the **Demo** to see it work, then complete **Your Turn** by replacing every `___` placeholder. Run the **grader** cell at the end &mdash; it prints `[PASS]` / `[FAIL]` / `[TODO]` and a final `Score`. Aim for a full score.
#
# **Reference:** [Module 1 slides &mdash; A short history of AI](../../presentation/day1-module1-understanding-ai-and-its-evolution.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html) &nbsp;&middot;&nbsp; [All Module 1 labs](./index.html)

# %%
# Setup -- run me first
import os
WORK = os.path.join(os.environ.get("TEMP") or os.environ.get("TMP") or "/tmp", "biaa-lab-01-03")
os.makedirs(WORK, exist_ok=True)
print("Working dir:", WORK)

# %% [markdown]
# ## Concept
# AI is ~70 years old and moved in waves &mdash; booms followed by **"AI winters"** when hype
# outran results. The modern wave began in **2012** (deep learning) and **2017** (the transformer).

# %%
# DEMO
milestones = [
    (1950, "Turing asks: can machines think?"),
    (1956, "Dartmouth workshop coins the term 'Artificial Intelligence'"),
    (1997, "Deep Blue beats world chess champion Kasparov"),
]
for year, ev in sorted(milestones):
    print(year, "-", ev)

# %% [markdown]
# ## Your Turn
# Add the **three** milestones that define the modern era, then compute two numbers.

# %%
my_milestones = [
    (1950, "Turing test"),
    (1956, "term 'AI' coined"),
    (1997, "Deep Blue"),
    # TODO: add (2012, "..."), (2017, "..."), (2022, "...")
    ("___", "___"),
    ("___", "___"),
    ("___", "___"),
]

# years from the Dartmouth workshop (1956) to ChatGPT (2022):
years_to_chatgpt = "___"   # TODO: compute 2022 - 1956

def has_year(y): return any(m[0] == y for m in my_milestones)
try:
    for y, ev in sorted(my_milestones):
        print(y, "-", ev)
except TypeError:
    print("Replace the (\"___\", \"___\") rows with real (year, text) entries, then re-run.")

# %%
# === Auto-grader: run after filling the blanks above ===
_results = []
def _rec(label, status, extra=""):
    _results.append(status); print(f"[{status}] {label}" + (f" -- {extra}" if extra else ""))
def expect(label, got, want):
    if got == "___" or got is None: _rec(label, "TODO")
    elif got == want: _rec(label, "PASS")
    else: _rec(label, "FAIL", f"got {got!r}")
def expect_true(label, fn):
    try: _rec(label, "PASS" if fn() else "FAIL")
    except Exception as e: _rec(label, "TODO", type(e).__name__)

expect_true("2012 (deep learning) added", lambda: has_year(2012))
expect_true("2017 (transformer) added", lambda: has_year(2017))
expect_true("2022 (ChatGPT) added", lambda: has_year(2022))
expect("years 1956 -> 2022", years_to_chatgpt, 66)

_p = _results.count("PASS")
print(f"\nScore: {_p}/{len(_results)}")
print("All checks passed -- lab complete!" if _p == len(_results) else "Keep going: fill the blanks marked ___ and re-run.")

# %% [markdown]
# ---
# ### Key takeaway
# Capability scales with **data + compute + algorithms**. Those three crossing a threshold around 2012 is what ended the last winter.
#
# [&#8592; All Module 1 labs](./index.html) &nbsp;&middot;&nbsp; [Module 1 slides](../../presentation/day1-module1-understanding-ai-and-its-evolution.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html)
#
# <sub>&copy; 2026 Gheware DevOps &amp; Agentic AI &middot; Building Intelligent AI Agents &middot; devops.gheware.com &middot; Trainer: Rajesh Gheware</sub>
