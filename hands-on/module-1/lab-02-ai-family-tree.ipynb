# %% [markdown]
# # Lab 1.2 &mdash; The AI Family Tree: AI &sup; ML &sup; DL &sup; GenAI
#
# **Level:** 🟢 Beginner &nbsp;|&nbsp; **Est. time:** 15 min &nbsp;|&nbsp; **Day 1 &middot; Module 1 &mdash; Understanding AI &amp; its Evolution**
#
# ### What you'll do
# - Understand that AI, ML, deep learning and generative AI are nested, not separate
# - Classify real-world technologies into the correct ring
# - Build the habit of asking 'which ring?' when someone says 'AI'
#
# > **How this lab works (experiential flow):** read the **Concept**, run the **Demo** to see it work, then complete **Your Turn** by replacing every `___` placeholder. Run the **grader** cell at the end &mdash; it prints `[PASS]` / `[FAIL]` / `[TODO]` and a final `Score`. Aim for a full score.
#
# **Reference:** [Module 1 slides &mdash; AI contains ML contains DL contains GenAI](../../presentation/day1-module1-understanding-ai-and-its-evolution.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html) &nbsp;&middot;&nbsp; [All Module 1 labs](./index.html)

# %%
# Setup -- run me first
import os
WORK = "/tmp/biaa-lab-01-02"
os.makedirs(WORK, exist_ok=True)
print("Working dir:", WORK)

# %% [markdown]
# ## Concept
# The terms nest like Russian dolls:
# **AI** (any machine intelligence) &sup; **ML** (learns from data) &sup; **Deep Learning**
# (neural networks) &sup; **Generative AI** (creates content). A rule-based system is AI but *not* ML.

# %%
# DEMO
RINGS = {
    "AI":    "any machine that mimics intelligence (incl. hand-written rules)",
    "ML":    "learns patterns from data (no neural net required)",
    "DL":    "machine learning with deep neural networks",
    "GenAI": "deep learning that creates text / images / code",
}
for k, v in RINGS.items():
    print(f"{k:6} = {v}")

# %% [markdown]
# ## Your Turn
# For each technology, fill in the **innermost** ring it belongs to: `"AI"`, `"ML"`, `"DL"` or `"GenAI"`.

# %%
answers = {
    "A hand-coded chess rulebook":            "___",
    "A spam filter trained on labelled email": "___",
    "A deep neural network that reads x-rays": "___",
    "ChatGPT writing an email":                "___",
    "A decision tree on a spreadsheet":        "___",
    "An image-generating diffusion model":     "___",
}
for tech, ring in answers.items():
    print(f"{ring:6} <- {tech}")

# %%
# === Auto-grader: run after filling the blanks above ===
_results = []
def _rec(label, status, extra=""):
    _results.append(status); print(f"[{status}] {label}" + (f" -- {extra}" if extra else ""))
def expect(label, got, want):
    if got == "___" or got is None: _rec(label, "TODO")
    elif got == want: _rec(label, "PASS")
    else: _rec(label, "FAIL", f"got {got!r}")
def expect_true(label, fn):
    try: _rec(label, "PASS" if fn() else "FAIL")
    except Exception as e: _rec(label, "TODO", type(e).__name__)

KEY = {
  "A hand-coded chess rulebook": "AI",
  "A spam filter trained on labelled email": "ML",
  "A deep neural network that reads x-rays": "DL",
  "ChatGPT writing an email": "GenAI",
  "A decision tree on a spreadsheet": "ML",
  "An image-generating diffusion model": "GenAI",
}
for tech, want in KEY.items():
    expect(tech[:34], answers.get(tech), want)

_p = _results.count("PASS")
print(f"\nScore: {_p}/{len(_results)}")
print("All checks passed -- lab complete!" if _p == len(_results) else "Keep going: fill the blanks marked ___ and re-run.")

# %% [markdown]
# ---
# ### Key takeaway
# When anyone says 'AI', ask **which ring**. Agentic AI (the course goal) wraps the **GenAI** ring with tools and a goal.
#
# [&#8592; All Module 1 labs](./index.html) &nbsp;&middot;&nbsp; [Module 1 slides](../../presentation/day1-module1-understanding-ai-and-its-evolution.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html)
#
# <sub>&copy; 2026 Gheware DevOps &amp; Agentic AI &middot; Building Intelligent AI Agents &middot; devops.gheware.com &middot; Trainer: Rajesh Gheware</sub>
