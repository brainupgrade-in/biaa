# %% [markdown]
# # Lab 1.5 &mdash; Three Ways Machines Learn
#
# **Level:** 🟢 Beginner &nbsp;|&nbsp; **Est. time:** 15 min &nbsp;|&nbsp; **Day 1 &middot; Module 1 &mdash; Understanding AI &amp; its Evolution**
#
# ### What you'll do
# - Tell supervised, unsupervised and reinforcement learning apart
# - Match real tasks to the right learning type
# - Recognise which days of the course use each
#
# > **How this lab works (experiential flow):** read the **Concept**, run the **Demo** to see it work, then complete **Your Turn** by replacing every `___` placeholder. Run the **grader** cell at the end &mdash; it prints `[PASS]` / `[FAIL]` / `[TODO]` and a final `Score`. Aim for a full score.
#
# **Reference:** [Module 1 slides &mdash; Three ways machines learn](../../presentation/day1-module1-understanding-ai-and-its-evolution.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html) &nbsp;&middot;&nbsp; [All Module 1 labs](./index.html)

# %%
# Setup -- run me first
import os
WORK = "/tmp/biaa-lab-01-05"
os.makedirs(WORK, exist_ok=True)
print("Working dir:", WORK)

# %% [markdown]
# ## Concept
# - **Supervised:** learn from *labelled* examples (input + right answer).
# - **Unsupervised:** find *structure* with no labels (grouping, embeddings).
# - **Reinforcement:** learn by *trial, reward & error* toward a goal.

# %%
# DEMO
print("supervised    : photo -> 'cat'   (labelled)")
print("unsupervised  : group shoppers by behaviour (no labels)")
print("reinforcement : a bot learns a game from reward")

# %% [markdown]
# ## Your Turn
# Label each task `"supervised"`, `"unsupervised"` or `"reinforcement"`.

# %%
answers = {
    "Predict house price from labelled past sales":       "___",
    "Group customers into segments with no labels":       "___",
    "Teach a robot to walk using rewards":                "___",
    "Classify email as spam/ham from labelled data":      "___",
    "Discover topics in a pile of unlabelled documents":  "___",
    "Train a game agent by trial and reward":             "___",
}
for task, t in answers.items(): print(f'{t:14} <- {task}')

# %%
# === Auto-grader: run after filling the blanks above ===
_results = []
def _rec(label, status, extra=""):
    _results.append(status); print(f"[{status}] {label}" + (f" -- {extra}" if extra else ""))
def expect(label, got, want):
    if got == "___" or got is None: _rec(label, "TODO")
    elif got == want: _rec(label, "PASS")
    else: _rec(label, "FAIL", f"got {got!r}")
def expect_true(label, fn):
    try: _rec(label, "PASS" if fn() else "FAIL")
    except Exception as e: _rec(label, "TODO", type(e).__name__)

KEY = {
  "Predict house price from labelled past sales": "supervised",
  "Group customers into segments with no labels": "unsupervised",
  "Teach a robot to walk using rewards": "reinforcement",
  "Classify email as spam/ham from labelled data": "supervised",
  "Discover topics in a pile of unlabelled documents": "unsupervised",
  "Train a game agent by trial and reward": "reinforcement",
}
for k, want in KEY.items():
    expect(k[:34], answers.get(k), want)

_p = _results.count("PASS")
print(f"\nScore: {_p}/{len(_results)}")
print("All checks passed -- lab complete!" if _p == len(_results) else "Keep going: fill the blanks marked ___ and re-run.")

# %% [markdown]
# ---
# ### Key takeaway
# This course rests mostly on **supervised learning** + huge **pre-trained** models. You'll meet all three ideas, intuition-first.
#
# [&#8592; All Module 1 labs](./index.html) &nbsp;&middot;&nbsp; [Module 1 slides](../../presentation/day1-module1-understanding-ai-and-its-evolution.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html)
#
# <sub>&copy; 2026 Gheware DevOps &amp; Agentic AI &middot; Building Intelligent AI Agents &middot; devops.gheware.com &middot; Trainer: Rajesh Gheware</sub>
