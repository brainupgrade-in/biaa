# %% [markdown]
# > ## SOLUTION / ANSWER KEY &mdash; Lab 4.8
# > This is the **completed** notebook (all `___` blanks filled). For the student version, open
# > [`../lab-08-evaluation-metrics.ipynb`](../lab-08-evaluation-metrics.ipynb). Trainer use &mdash; or self-check after you've tried it yourself.

# %% [markdown]
# # Lab 4.8 &mdash; Beyond Accuracy: Precision, Recall & Confusion
#
# **Level:** Intermediate &nbsp;|&nbsp; **Est. time:** 30 min &nbsp;|&nbsp; **Day 2 &middot; Module 4 &mdash; Pre-trained Models & Fine-tuning**
#
# ### What you'll do
# - Build a confusion matrix from predictions
# - Compute precision and recall for the positive class
# - See why accuracy alone can mislead
#
# > **How this lab works (experiential flow):** read the **Concept**, run the **Demo** to see it work, then complete **Your Turn** by replacing every `___` placeholder. Run the **grader** cell at the end &mdash; it prints `[PASS]` / `[FAIL]` / `[TODO]` and a final `Score`. Aim for a full score.
#
# **Reference:** [Module 4 slides &mdash; Evaluation](../../presentation/day2-module4-pretrained-models-and-fine-tuning.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html) &nbsp;&middot;&nbsp; [All Module 4 labs](./index.html)

# %%
# Setup -- run me first
import os
WORK = "/tmp/biaa-lab-04-08"
os.makedirs(WORK, exist_ok=True)
print("Working dir:", WORK)

# %% [markdown]
# ## Concept
# Accuracy hides *how* a model is wrong. The **confusion matrix** counts TP/FP/FN/TN.
# **Precision** = TP / (TP+FP) ("when it says positive, is it right?").
# **Recall** = TP / (TP+FN) ("of the real positives, how many did it catch?").

# %%
# DEMO -- true vs predicted labels
y_true = [1,1,1,0,0,0,1,0]
y_pred = [1,0,1,0,1,0,1,0]
print("true:", y_true)
print("pred:", y_pred)

# %% [markdown]
# ## Your Turn
# Compute TP/FP/FN, then precision and recall for the positive class (label 1).

# %%
y_true = [1,1,1,0,0,0,1,0]
y_pred = [1,0,1,0,1,0,1,0]

def counts():
    TP = sum(1 for t,p in zip(y_true,y_pred) if t==1 and p==1)
    FP = sum(1 for t,p in zip(y_true,y_pred) if t==0 and p==1)
    FN = sum(1 for t,p in zip(y_true,y_pred) if t==1 and p==0)
    return TP, FP, FN

def precision():
    TP, FP, FN = counts()
    return TP / (TP + FP)
def recall():
    TP, FP, FN = counts()
    return TP / (TP + FN)

try: print('counts(TP,FP,FN):', counts(), '| precision:', round(precision(),3), '| recall:', round(recall(),3))
except Exception as e: print('Fill the blanks, then re-run.', type(e).__name__)

# %%
# === Auto-grader: run after filling the blanks above ===
_results = []
def _rec(label, status, extra=""):
    _results.append(status); print(f"[{status}] {label}" + (f" -- {extra}" if extra else ""))
def expect(label, got, want):
    if got == "___" or got is None: _rec(label, "TODO")
    elif got == want: _rec(label, "PASS")
    else: _rec(label, "FAIL", f"got {got!r}")
def expect_true(label, fn):
    try: _rec(label, "PASS" if fn() else "FAIL")
    except Exception as e: _rec(label, "TODO", type(e).__name__)

expect("TP,FP,FN counts", counts(), (3, 1, 1))
expect_true("precision == 0.75", lambda: abs(precision() - 0.75) < 1e-9)
expect_true("recall == 0.75", lambda: abs(recall() - 0.75) < 1e-9)
from sklearn.metrics import precision_score
expect_true("matches sklearn precision", lambda: abs(precision() - precision_score(y_true, y_pred)) < 1e-9)

_p = _results.count("PASS")
print(f"\nScore: {_p}/{len(_results)}")
print("All checks passed -- lab complete!" if _p == len(_results) else "Keep going: fill the blanks marked ___ and re-run.")

# %% [markdown]
# ---
# ### Key takeaway
# On imbalanced or high-stakes tasks, precision and recall matter more than accuracy. Always look at the confusion matrix before trusting a score.
#
# [&#8592; All Module 4 labs](./index.html) &nbsp;&middot;&nbsp; [Module 4 slides](../../presentation/day2-module4-pretrained-models-and-fine-tuning.html) &nbsp;&middot;&nbsp; [Course outline](../../course-outline-building-intelligent-ai-agents.html)
#
# <sub>&copy; 2026 Gheware DevOps &amp; Agentic AI &middot; Building Intelligent AI Agents &middot; devops.gheware.com &middot; Trainer: Rajesh Gheware</sub>
